# %%
import pandas as pd

# %%
df = pd.read_csv("DonorData.csv")
df.head()
# Out:
#    Donor No Company Name Surname  Forename Initials Title  Honours  \
# 0    367838          NaN  Austin  Lorraine        L   Mrs      NaN
# 1    367838          NaN  Austin  Lorraine        L   Mrs      NaN
# 2    367838          NaN  Austin  Lorraine        L   Mrs      NaN
# 3    367838          NaN  Austin  Lorraine        L   Mrs      NaN
# 4    367838          NaN  Austin  Lorraine        L   Mrs      NaN
#
#    Salutation  Position  Department  ...  GA Claim Amount  \
# 0  Mrs Austin       NaN         NaN  ...            £0.00
# 1  Mrs Austin       NaN         NaN  ...            £0.00
# 2  Mrs Austin       NaN         NaN  ...            £0.00
# 3  Mrs Austin       NaN         NaN  ...            £0.00
# 4  Mrs Austin       NaN         NaN  ...            £0.00
#
#    Aggregated Description GASDS Submission Ref  GASDS Claimed By  \
# 0                     NaN        Not Submitted               NaN
# 1                     NaN        Not Submitted               NaN
# ...
