# %%
import pandas as pd

data = pd.read_csv("donation_events_geocoded.csv")

# %%
filtered_data = (data[data["Postcode"]=="AB55 4AH"])

# %%
print(filtered_data["Month_Year"].nunique())
print(filtered_data["Month_Year"].unique())
# Out:
# 59
# ['01/2021' '01/2022' '01/2023' '01/2024' '01/2025' '02/2021' '02/2022'
#  '02/2023' '02/2024' '02/2025' '03/2021' '03/2022' '03/2023' '03/2024'
#  '03/2025' '04/2021' '04/2022' '04/2023' '04/2024' '04/2025' '05/2021'
#  '05/2022' '05/2023' '05/2024' '05/2025' '06/2021' '06/2022' '06/2023'
#  '06/2024' '06/2025' '07/2021' '07/2022' '07/2023' '07/2024' '07/2025'
#  '08/2021' '08/2022' '08/2023' '08/2024' '08/2025' '09/2021' '09/2022'
#  '09/2023' '09/2024' '09/2025' '10/2021' '10/2022' '10/2023' '10/2024'
#  '10/2025' '11/2021' '11/2022' '11/2023' '11/2024' '11/2025' '12/2021'
#  '12/2022' '12/2023' '12/2024']

# %%
# ("Counts in full dataset:")
(data["Source"].value_counts())
# Out:
# Source
# LSPSWP    138446
# LSPRDD     11371
# REGSOL      9713
# REGOLD      8101
# IMOGEN      7473
#            ...
# CFAMAT         1
# FIRDON         1
# EVTSPO         1
# WKTCSP         1
# CFALUE         1
# Name: count, Length: 134, dtype: int64

# %%
print(data["Source"].nunique())
print(data["Source"].unique())
# Out:
# 134
# ['REGOLD' 'REGSOL' 'LSPSWP' 'IMOGEN' 'LSPRDD' 'UNSDON' 'LSPLDD' 'LOTDON'
#  'IMOMTR' 'TFCSOL' 'APLXMS' 'LSPBBP' 'LOTWIN' 'CFADON' 'APLSUM' 'NWSSOL'
#  'SLEGEV' 'CFAPOT' 'CFACOY' 'CFACRP' 'CFAXMS' 'SLECEL' 'WKTDON' 'LSPRTK'
#  'CFATXT' 'APLSOL' 'TRKSPO' 'UNSLEG' 'CHLSPO' 'TRUSOL' 'LOLSOL' 'VRWSPO'
#  'CHLREG' 'GDRTKT' 'BMASPO' 'IMOREV' 'IMOCOL' 'XMSTRE' 'LEGSOL' 'FIRSPO'
#  'MIMREG' 'CPASOL' 'UNSTRU' 'SLESPO' 'CAPBUD' 'LOLDON' 'CFACSP' 'WKTSPO'
#  'QUZADM' 'LMASPO' 'WKTREG' 'REGGIL' 'TWIREG' 'CPADON' 'CPAGEN' 'CPAPOT'
#  'RPHREG' 'CPAMAT' 'CPACSP' 'TWISPO' 'UNSREG' 'GDRDON' 'CFAMER' 'SGRDON'
#  'IMOENV' 'LMAREG' 'QUZACT' 'CFAGEV' 'MIMSPO' 'XMSDON' 'BTKSPO' 'ATFREG'
#  'BTKREG' 'EBHREG' 'WIASPO' 'WKTBUS' 'MIMDON' 'TWIDON' 'SKYSPO' 'RPHSPO'
#  'EBHDON' 'SGRADM' 'CPAFND' 'CFABNG' 'CDDADM' 'CPACPA' 'APLBGP' 'LOLEVT'
#  'BMAREG' 'MDADON' 'CPAGEV' 'CFRFEE' 'EXTSKS' 'CFACPA' 'GOLREG' 'EXTWIS'
#  'SOMSOL' 'SOMEVT' 'SOMDON' 'EBHRAF' 'SMFFEE' 'IMOAPL' 'ATFRAF' 'SMFDON'
# ...
